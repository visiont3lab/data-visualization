# %% [markdown]
# #Complete Guide to Data Visualization with Python

# %%
from IPython.display import Image

# %%
#Image(url= "https://frenzy86.s3.eu-west-2.amazonaws.com/fav/xxxxxxxxx.PNG", width=400, height=300)

# %%
temporal = 'https://frenzy86.s3.eu-west-2.amazonaws.com/fav/visualization/temporal.csv'

# %%
#https://towardsdatascience.com/complete-guide-to-data-visualization-with-python-2dd74df12b5e

# %%
import pandas as pd
df = pd.read_csv(temporal)
df.head(10) #View first 10 data rows
# Out:
#           Mes  data science  machine learning  deep learning  categorical
# 0  2004-01-01            12                18              4            1
# 1  2004-02-01            12                21              2            1
# 2  2004-03-01             9                21              2            1
# 3  2004-04-01            10                16              4            1
# 4  2004-05-01             7                14              3            1
# 5  2004-06-01             9                17              3            1
# 6  2004-07-01             9                16              3            1
# 7  2004-08-01             7                14              3            1
# 8  2004-09-01            10                17              4            1
# 9  2004-10-01             8                17              4            1

# %%
df.describe()
# Out:
#        data science  machine learning  deep learning  categorical
# count    194.000000        194.000000     194.000000   194.000000
# mean      20.953608         27.396907      24.231959     0.257732
# std       23.951006         28.091490      34.476887     0.438517
# min        4.000000          7.000000       1.000000     0.000000
# 25%        6.000000          9.000000       2.000000     0.000000
# 50%        8.000000         13.000000       3.000000     0.000000
# 75%       26.750000         31.500000      34.000000     1.000000
# max      100.000000        100.000000     100.000000     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Mes               194 non-null    object
#  1   data science      194 non-null    int64
#  2   machine learning  194 non-null    int64
#  3   deep learning     194 non-null    int64
#  4   categorical       194 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.7+ KB

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
format_dict = {'data science':'${0:,.2f}', 'Mes':'{:%m-%Y}', 'machine learning':'{:.2%}'}
#We make sure that the Month column has datetime format
df['Mes'] = pd.to_datetime(df['Mes'])
#We apply the style to the visualization
df.head().style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Mes</th>        <th class="col_heading level0 col1" >data science</th>        <th class="col_heading level0 col2" >machine learning</th>        <th class="col_heading level0 col3" >deep learning</th>        <th class="col_heading level0 col4" >categorical</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row0_col0" class="data row0 col0" >01-2004</td>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row0_col1" class="data row0 col1" >$12.00</td>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row0_col2" class="data row0 col2" >1800.00%</td>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row0_col3" class="data row0 col3" >4</td>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row0_col4" class="data row0 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row1_col0" class="data row1 col0" >02-2004</td>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row1_col1" class="data row1 col1" >$12.00</td>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row1_col2" class="data row1 col2" >2100.00%</td>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row1_col3" class="data row1 col3" >2</td>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row1_col4" class="data row1 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row2_col0" class="data row2 col0" >03-2004</td>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row2_col1" class="data row2 col1" >$9.00</td>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row2_col2" class="data row2 col2" >2100.00%</td>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row2_col3" class="data row2 col3" >2</td>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row2_col4" class="data row2 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row3_col0" class="data row3 col0" >04-2004</td>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row3_col1" class="data row3 col1" >$10.00</td>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row3_col2" class="data row3 col2" >1600.00%</td>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row3_col3" class="data row3 col3" >4</td>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row3_col4" class="data row3 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row4_col0" class="data row4 col0" >05-2004</td>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row4_col1" class="data row4 col1" >$7.00</td>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row4_col2" class="data row4 col2" >1400.00%</td>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row4_col3" class="data row4 col3" >3</td>
#                         <td id="T_be0fa0d6_741e_11ea_99c9_0242ac1c0002row4_col4" class="data row4 col4" >1</td>
#             </tr>
#     </tbody></table>

# %%
format_dict = {'Mes':'{:%m-%Y}'} #Simplified format dictionary with values that do make sense for our data
df.head().style.format(format_dict).highlight_max(color='darkgreen').highlight_min(color='#ff0000')
# Out:
# <style  type="text/css" >
#     #T_bfee39da_741e_11ea_99c9_0242ac1c0002row0_col1 {
#             background-color:  darkgreen;
#             : ;
#         }    #T_bfee39da_741e_11ea_99c9_0242ac1c0002row0_col3 {
#             background-color:  darkgreen;
#             : ;
#         }    #T_bfee39da_741e_11ea_99c9_0242ac1c0002row0_col4 {
#             background-color:  darkgreen;
#             background-color:  #ff0000;
#         }    #T_bfee39da_741e_11ea_99c9_0242ac1c0002row1_col1 {
#             background-color:  darkgreen;
#             : ;
#         }    #T_bfee39da_741e_11ea_99c9_0242ac1c0002row1_col2 {
#             background-color:  darkgreen;
#             : ;
#         }    #T_bfee39da_741e_11ea_99c9_0242ac1c0002row1_col3 {
#             : ;
#             background-color:  #ff0000;
#         }    #T_bfee39da_741e_11ea_99c9_0242ac1c0002row1_col4 {
#             background-color:  darkgreen;
#             background-color:  #ff0000;
#         }    #T_bfee39da_741e_11ea_99c9_0242ac1c0002row2_col2 {
#             background-color:  darkgreen;
#             : ;
#         }    #T_bfee39da_741e_11ea_99c9_0242ac1c0002row2_col3 {
#             : ;
#             background-color:  #ff0000;
#         }    #T_bfee39da_741e_11ea_99c9_0242ac1c0002row2_col4 {
#             background-color:  darkgreen;
#             background-color:  #ff0000;
#         }    #T_bfee39da_741e_11ea_99c9_0242ac1c0002row3_col3 {
#             background-color:  darkgreen;
#             : ;
#         }    #T_bfee39da_741e_11ea_99c9_0242ac1c0002row3_col4 {
#             background-color:  darkgreen;
#             background-color:  #ff0000;
#         }    #T_bfee39da_741e_11ea_99c9_0242ac1c0002row4_col1 {
#             : ;
#             background-color:  #ff0000;
#         }    #T_bfee39da_741e_11ea_99c9_0242ac1c0002row4_col2 {
#             : ;
#             background-color:  #ff0000;
#         }    #T_bfee39da_741e_11ea_99c9_0242ac1c0002row4_col4 {
#             background-color:  darkgreen;
#             background-color:  #ff0000;
#         }</style><table id="T_bfee39da_741e_11ea_99c9_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Mes</th>        <th class="col_heading level0 col1" >data science</th>        <th class="col_heading level0 col2" >machine learning</th>        <th class="col_heading level0 col3" >deep learning</th>        <th class="col_heading level0 col4" >categorical</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bfee39da_741e_11ea_99c9_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row0_col0" class="data row0 col0" >01-2004</td>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row0_col1" class="data row0 col1" >12</td>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row0_col2" class="data row0 col2" >18</td>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row0_col3" class="data row0 col3" >4</td>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row0_col4" class="data row0 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_bfee39da_741e_11ea_99c9_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row1_col0" class="data row1 col0" >02-2004</td>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row1_col1" class="data row1 col1" >12</td>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row1_col2" class="data row1 col2" >21</td>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row1_col3" class="data row1 col3" >2</td>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row1_col4" class="data row1 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_bfee39da_741e_11ea_99c9_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row2_col0" class="data row2 col0" >03-2004</td>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row2_col1" class="data row2 col1" >9</td>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row2_col2" class="data row2 col2" >21</td>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row2_col3" class="data row2 col3" >2</td>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row2_col4" class="data row2 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_bfee39da_741e_11ea_99c9_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row3_col0" class="data row3 col0" >04-2004</td>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row3_col1" class="data row3 col1" >10</td>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row3_col2" class="data row3 col2" >16</td>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row3_col3" class="data row3 col3" >4</td>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row3_col4" class="data row3 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_bfee39da_741e_11ea_99c9_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row4_col0" class="data row4 col0" >05-2004</td>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row4_col1" class="data row4 col1" >7</td>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row4_col2" class="data row4 col2" >14</td>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row4_col3" class="data row4 col3" >3</td>
#                         <td id="T_bfee39da_741e_11ea_99c9_0242ac1c0002row4_col4" class="data row4 col4" >1</td>
#             </tr>
#     </tbody></table>

# %%
df.head(10).style.format(format_dict).background_gradient(subset=['data science', 'machine learning'], cmap='BuGn')
# Out:
# <style  type="text/css" >
#     #T_c1a73ace_741e_11ea_99c9_0242ac1c0002row0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_c1a73ace_741e_11ea_99c9_0242ac1c0002row0_col2 {
#             background-color:  #51b689;
#             color:  #000000;
#         }    #T_c1a73ace_741e_11ea_99c9_0242ac1c0002row1_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_c1a73ace_741e_11ea_99c9_0242ac1c0002row1_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_c1a73ace_741e_11ea_99c9_0242ac1c0002row2_col1 {
#             background-color:  #8fd4c2;
#             color:  #000000;
#         }    #T_c1a73ace_741e_11ea_99c9_0242ac1c0002row2_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_c1a73ace_741e_11ea_99c9_0242ac1c0002row3_col1 {
#             background-color:  #48b27f;
#             color:  #000000;
#         }    #T_c1a73ace_741e_11ea_99c9_0242ac1c0002row3_col2 {
#             background-color:  #bde6de;
#             color:  #000000;
#         }    #T_c1a73ace_741e_11ea_99c9_0242ac1c0002row4_col1 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }    #T_c1a73ace_741e_11ea_99c9_0242ac1c0002row4_col2 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }    #T_c1a73ace_741e_11ea_99c9_0242ac1c0002row5_col1 {
#             background-color:  #8fd4c2;
#             color:  #000000;
#         }    #T_c1a73ace_741e_11ea_99c9_0242ac1c0002row5_col2 {
#             background-color:  #84cfb9;
#             color:  #000000;
#         }    #T_c1a73ace_741e_11ea_99c9_0242ac1c0002row6_col1 {
#             background-color:  #8fd4c2;
#             color:  #000000;
#         }    #T_c1a73ace_741e_11ea_99c9_0242ac1c0002row6_col2 {
#             background-color:  #bde6de;
#             color:  #000000;
#         }    #T_c1a73ace_741e_11ea_99c9_0242ac1c0002row7_col1 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }    #T_c1a73ace_741e_11ea_99c9_0242ac1c0002row7_col2 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }    #T_c1a73ace_741e_11ea_99c9_0242ac1c0002row8_col1 {
#             background-color:  #48b27f;
#             color:  #000000;
#         }    #T_c1a73ace_741e_11ea_99c9_0242ac1c0002row8_col2 {
#             background-color:  #84cfb9;
#             color:  #000000;
#         }    #T_c1a73ace_741e_11ea_99c9_0242ac1c0002row9_col1 {
#             background-color:  #d6f0ee;
#             color:  #000000;
#         }    #T_c1a73ace_741e_11ea_99c9_0242ac1c0002row9_col2 {
#             background-color:  #84cfb9;
#             color:  #000000;
#         }</style><table id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Mes</th>        <th class="col_heading level0 col1" >data science</th>        <th class="col_heading level0 col2" >machine learning</th>        <th class="col_heading level0 col3" >deep learning</th>        <th class="col_heading level0 col4" >categorical</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row0_col0" class="data row0 col0" >01-2004</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row0_col1" class="data row0 col1" >12</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row0_col2" class="data row0 col2" >18</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row0_col3" class="data row0 col3" >4</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row0_col4" class="data row0 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row1_col0" class="data row1 col0" >02-2004</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row1_col1" class="data row1 col1" >12</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row1_col2" class="data row1 col2" >21</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row1_col3" class="data row1 col3" >2</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row1_col4" class="data row1 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row2_col0" class="data row2 col0" >03-2004</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row2_col1" class="data row2 col1" >9</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row2_col2" class="data row2 col2" >21</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row2_col3" class="data row2 col3" >2</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row2_col4" class="data row2 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row3_col0" class="data row3 col0" >04-2004</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row3_col1" class="data row3 col1" >10</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row3_col2" class="data row3 col2" >16</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row3_col3" class="data row3 col3" >4</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row3_col4" class="data row3 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row4_col0" class="data row4 col0" >05-2004</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row4_col1" class="data row4 col1" >7</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row4_col2" class="data row4 col2" >14</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row4_col3" class="data row4 col3" >3</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row4_col4" class="data row4 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row5_col0" class="data row5 col0" >06-2004</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row5_col1" class="data row5 col1" >9</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row5_col2" class="data row5 col2" >17</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row5_col3" class="data row5 col3" >3</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row5_col4" class="data row5 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row6_col0" class="data row6 col0" >07-2004</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row6_col1" class="data row6 col1" >9</td>
#                         <td id="T_c1a73ace_741e_11ea_99c9_0242ac1c0002row6_col2" class="data row6 col2" >16</td>
#                         <td id

# %%
df.head().style.format(format_dict).bar(color='red', subset=['data science', 'deep learning'])
# Out:
# <style  type="text/css" >
#     #T_c3d30166_741e_11ea_99c9_0242ac1c0002row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 100.0%, transparent 100.0%);
#         }    #T_c3d30166_741e_11ea_99c9_0242ac1c0002row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 100.0%, transparent 100.0%);
#         }    #T_c3d30166_741e_11ea_99c9_0242ac1c0002row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 100.0%, transparent 100.0%);
#         }    #T_c3d30166_741e_11ea_99c9_0242ac1c0002row1_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_c3d30166_741e_11ea_99c9_0242ac1c0002row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 40.0%, transparent 40.0%);
#         }    #T_c3d30166_741e_11ea_99c9_0242ac1c0002row2_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_c3d30166_741e_11ea_99c9_0242ac1c0002row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 60.0%, transparent 60.0%);
#         }    #T_c3d30166_741e_11ea_99c9_0242ac1c0002row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 100.0%, transparent 100.0%);
#         }    #T_c3d30166_741e_11ea_99c9_0242ac1c0002row4_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_c3d30166_741e_11ea_99c9_0242ac1c0002row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 50.0%, transparent 50.0%);
#         }</style><table id="T_c3d30166_741e_11ea_99c9_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Mes</th>        <th class="col_heading level0 col1" >data science</th>        <th class="col_heading level0 col2" >machine learning</th>        <th class="col_heading level0 col3" >deep learning</th>        <th class="col_heading level0 col4" >categorical</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c3d30166_741e_11ea_99c9_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row0_col0" class="data row0 col0" >01-2004</td>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row0_col1" class="data row0 col1" >12</td>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row0_col2" class="data row0 col2" >18</td>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row0_col3" class="data row0 col3" >4</td>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row0_col4" class="data row0 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_c3d30166_741e_11ea_99c9_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row1_col0" class="data row1 col0" >02-2004</td>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row1_col1" class="data row1 col1" >12</td>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row1_col2" class="data row1 col2" >21</td>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row1_col3" class="data row1 col3" >2</td>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row1_col4" class="data row1 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_c3d30166_741e_11ea_99c9_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row2_col0" class="data row2 col0" >03-2004</td>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row2_col1" class="data row2 col1" >9</td>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row2_col2" class="data row2 col2" >21</td>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row2_col3" class="data row2 col3" >2</td>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row2_col4" class="data row2 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_c3d30166_741e_11ea_99c9_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row3_col0" class="data row3 col0" >04-2004</td>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row3_col1" class="data row3 col1" >10</td>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row3_col2" class="data row3 col2" >16</td>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row3_col3" class="data row3 col3" >4</td>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row3_col4" class="data row3 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_c3d30166_741e_11ea_99c9_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row4_col0" class="data row4 col0" >05-2004</td>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row4_col1" class="data row4 col1" >7</td>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row4_col2" class="data row4 col2" >14</td>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row4_col3" class="data row4 col3" >3</td>
#                         <td id="T_c3d30166_741e_11ea_99c9_0242ac1c0002row4_col4" class="data row4 col4" >1</td>
#             </tr>
#     </tbody></table>

# %%
df.head(10).style.format(format_dict).background_gradient(subset=['data science', 'machine learning'], cmap='BuGn').highlight_max(color='yellow')
# Out:
# <style  type="text/css" >
#     #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#             background-color:  yellow;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row0_col2 {
#             background-color:  #51b689;
#             color:  #000000;
#             : ;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row0_col3 {
#             background-color:  yellow;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row0_col4 {
#             background-color:  yellow;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row1_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#             background-color:  yellow;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row1_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#             background-color:  yellow;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row1_col4 {
#             background-color:  yellow;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row2_col1 {
#             background-color:  #8fd4c2;
#             color:  #000000;
#             : ;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row2_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#             background-color:  yellow;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row2_col4 {
#             background-color:  yellow;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row3_col1 {
#             background-color:  #48b27f;
#             color:  #000000;
#             : ;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row3_col2 {
#             background-color:  #bde6de;
#             color:  #000000;
#             : ;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row3_col3 {
#             background-color:  yellow;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row3_col4 {
#             background-color:  yellow;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row4_col1 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#             : ;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row4_col2 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#             : ;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row4_col4 {
#             background-color:  yellow;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row5_col1 {
#             background-color:  #8fd4c2;
#             color:  #000000;
#             : ;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row5_col2 {
#             background-color:  #84cfb9;
#             color:  #000000;
#             : ;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row5_col4 {
#             background-color:  yellow;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row6_col1 {
#             background-color:  #8fd4c2;
#             color:  #000000;
#             : ;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row6_col2 {
#             background-color:  #bde6de;
#             color:  #000000;
#             : ;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row6_col4 {
#             background-color:  yellow;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row7_col1 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#             : ;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row7_col2 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#             : ;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row7_col4 {
#             background-color:  yellow;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row8_col1 {
#             background-color:  #48b27f;
#             color:  #000000;
#             : ;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row8_col2 {
#             background-color:  #84cfb9;
#             color:  #000000;
#             : ;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row8_col3 {
#             background-color:  yellow;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row8_col4 {
#             background-color:  yellow;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row9_col1 {
#             background-color:  #d6f0ee;
#             color:  #000000;
#             : ;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row9_col2 {
#             background-color:  #84cfb9;
#             color:  #000000;
#             : ;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row9_col3 {
#             background-color:  yellow;
#         }    #T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row9_col4 {
#             background-color:  yellow;
#         }</style><table id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Mes</th>        <th class="col_heading level0 col1" >data science</th>        <th class="col_heading level0 col2" >machine learning</th>        <th class="col_heading level0 col3" >deep learning</th>        <th class="col_heading level0 col4" >categorical</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row0_col0" class="data row0 col0" >01-2004</td>
#                         <td id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row0_col1" class="data row0 col1" >12</td>
#                         <td id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row0_col2" class="data row0 col2" >18</td>
#                         <td id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row0_col3" class="data row0 col3" >4</td>
#                         <td id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row0_col4" class="data row0 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row1_col0" class="data row1 col0" >02-2004</td>
#                         <td id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row1_col1" class="data row1 col1" >12</td>
#                         <td id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row1_col2" class="data row1 col2" >21</td>
#                         <td id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row1_col3" class="data row1 col3" >2</td>
#                         <td id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row1_col4" class="data row1 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row2_col0" class="data row2 col0" >03-2004</td>
#                         <td id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row2_col1" class="data row2 col1" >9</td>
#                         <td id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row2_col2" class="data row2 col2" >21</td>
#                         <td id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row2_col3" class="data row2 col3" >2</td>
#                         <td id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row2_col4" class="data row2 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row3_col0" class="data row3 col0" >04-2004</td>
#                         <td id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row3_col1" class="data row3 col1" >10</td>
#                         <td id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row3_col2" class="data row3 col2" >16</td>
#                         <td id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row3_col3" class="data row3 col3" >4</td>
#                         <td id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002row3_col4" class="data row3 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d1f2d4_741e_11ea_99c9_0242ac1c0002level0_row4" class="ro

# %% [markdown]
# #Pandas Profiling
# Pandas profiling is a library that generates interactive reports with our data, we can see the distribution of the data, the types of data, possible problems it might have. It is very easy to use, with only 3 lines we can generate a report that we can send to anyone and that can be used even if you do not know programming.

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
#prof.to_file(output_file='informe.html')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-59729e9af009> in <module>()
#       1 from pandas_profiling import ProfileReport
# ----> 2 prof = ProfileReport(df)
#       3 #prof.to_file(output_file='informe.html')
#
# /usr/local/lib/python3.6/dist-packages/pandas_profiling/__init__.py in __init__(self, df, **kwargs)
#      64         sample = kwargs.get('sample', df.head())
#      65
# ---> 66         description_set = describe(df, **kwargs)
#      67
#      68         self.html = to_html(sample,
#
# /usr/local/lib/python3.6/dist-packages/pandas_profiling/describe.py in describe(df, bins, check_correlation, correlation_threshold, correlation_overrides, check_recoded, pool_size, **kwargs)
#     390             if name not in names:
#     391                 names.append(name)
# --> 392     variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
#     393     variable_stats.columns.names = df.columns.names
#     394
#
# TypeError: concat() got an unexpected keyword argument 'join_axes'

# %%
'https://frenzy86.s3.eu-west-2.amazonaws.com/fav/visualization/informe.html'
# Out:
# 'https://frenzy86.s3.eu-west-2.amazonaws.com/fav/visualization/informe.html'

# %% [markdown]
# #Bokeh
# Bokeh is a library that allows you to generate interactive graphics. We can export them to an HTML document that we can share with anyone who has a web browser.

# %%
from bokeh.plotting import figure, output_file, save
output_file('data_science_popularity.html')

# %%
p = figure(title='data science', x_axis_label='Mes', y_axis_label='data science')
p.line(df['Mes'], df['data science'], legend='popularity', line_width=2)
save(p)
# Out:
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# '/content/data_science_popularity.html'

# %% [markdown]
# #Folium

# %%
44.4807035,11.3712528

# %%
import folium
m1 = folium.Map(location=[44.48, 11.37], tiles='openstreetmap', zoom_start=150)
m1.save('map1.html')

# %%
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m2 = folium.Map(location=[41.38, 2.17], tiles='openstreetmap', zoom_start=16)
folium.Marker([41.38, 2.176], popup='<i>You can use whatever HTML code you want</i>', tooltip='click here').add_to(m2)
folium.Marker([41.38, 2.174], popup='<b>You can use whatever HTML code you want</b>', tooltip='dont click here').add_to(m2)
m2.save('map2.html')

# %%
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapa = 'https://frenzy86.s3.eu-west-2.amazonaws.com/fav/visualization/mapa.csv'
# !pip install geopandas
# Out:
# Collecting geopandas
#   Downloading https://files.pythonhosted.org/packages/83/c5/3cf9cdc39a6f2552922f79915f36b45a95b71fd343cfc51170a5b6ddb6e8/geopandas-0.7.0-py2.py3-none-any.whl (928kB)
#      |████████████████████████████████| 931kB 4.8MB/s
# Collecting pyproj>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/77/15/d93f446d253d26b91553f86cf21049183e9b0f51f8c8e6cb2cff081bcc02/pyproj-2.5.0-cp36-cp36m-manylinux2010_x86_64.whl (10.4MB)
#      |████████████████████████████████| 10.4MB 45.8MB/s
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from geopandas) (0.25.3)
# Requirement already satisfied: shapely in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.7.0)
# Collecting fiona
#   Downloading https://files.pythonhosted.org/packages/ec/20/4e63bc5c6e62df889297b382c3ccd4a7a488b00946aaaf81a118158c6f09/Fiona-1.8.13.post1-cp36-cp36m-manylinux1_x86_64.whl (14.7MB)
#      |████████████████████████████████| 14.7MB 46.0MB/s
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (1.17.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (2.6.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (2018.9)
# Collecting cligj>=0.5
#   Downloading https://files.pythonhosted.org/packages/e4/be/30a58b4b0733850280d01f8bd132591b4668ed5c7046761098d665ac2174/cligj-0.5.0-py3-none-any.whl
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (19.3.0)
# Collecting click-plugins>=1.0
#   Downloading https://files.pythonhosted.org/packages/e9/da/824b92d9942f4e472702488857914bdd50f73021efea15b4cad9aca8ecef/click_plugins-1.1.1-py2.py3-none-any.whl
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (7.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (1.12.0)
# Collecting munch
#   Downloading https://files.pythonhosted.org/packages/cc/ab/85d8da5c9a45e072301beb37ad7f833cd344e04c817d97e0cc75681d248f/munch-2.5.0-py2.py3-none-any.whl
# Installing collected packages: pyproj, cligj, click-plugins, munch, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.5.0 fiona-1.8.13.post1 geopandas-0.7.0 munch-2.5.0 pyproj-2.5.0

# %%
from geopandas.tools import geocode
df2 = pd.read_csv(mapa)
df2.dropna(axis=0, inplace=True)
df2['geometry'] = geocode(df2['País'], provider='nominatim')['geometry'] #It may take a while because it downloads a lot of data.
df2['Latitude'] = df2['geometry'].apply(lambda l: l.y)
df2['Longitude'] = df2['geometry'].apply(lambda l: l.x)
# Out:
# /usr/local/lib/python3.6/dist-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning

# %%
m3 = folium.Map(location=[39.326234,-4.838065], tiles='openstreetmap', zoom_start=3)
def color_producer(val):
	if val <= 50:
		return 'red'
	else:
		return 'green'
for i in range(0,len(df2)):
	folium.Circle(location=[df2.iloc[i]['Latitude'], df2.iloc[i]['Longitude']], radius=5000*df2.iloc[i]['data science'], color=color_producer(df2.iloc[i]['data science'])).add_to(m3)
m3.save('map3.html')

# %%
m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[45.5236, -122.6750])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Map(
    location=[45.5236, -122.6750],
    tiles='Stamen Toner',
    zoom_start=13)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Markers

# %%
m = folium.Map(
    location=[45.372, -121.6972],
    zoom_start=12,
    tiles='Stamen Terrain'
)

tooltip = 'Click me!'

folium.Marker([45.3288, -121.6625], popup='<i>Mt. Hood Meadows</i>', tooltip=tooltip).add_to(m)
folium.Marker([45.3311, -121.7113], popup='<b>Timberline Lodge</b>', tooltip=tooltip).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Color and Icons

# %%
# color and icon
m = folium.Map(
    location=[45.372, -121.6972],
    zoom_start=12,
    tiles='Stamen Terrain'
)

folium.Marker(
    location=[45.3288, -121.6625],
    popup='Mt. Hood Meadows',
    icon=folium.Icon(icon='cloud')
).add_to(m)

folium.Marker(
    location=[45.3311, -121.7113],
    popup='Timberline Lodge',
    icon=folium.Icon(color='green')
).add_to(m)

folium.Marker(
    location=[45.3300, -121.6823],
    popup='Some Other Location',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Polylines

# %%
m = folium.Map(
    width='80%', 
    height='80%',
    location=[45.33, -121.69],
    zoom_start=12,
    tiles='Stamen Terrain'
)
folium.PolyLine([[45.3288, -121.6625],[45.3311, -121.7113]]).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Choropleth maps

# %%
base = 'https://github.com/python-visualization/folium/raw/master/examples/data/'
state_geo = base + 'us-states.json'

state_unemployment = base + 'US_Unemployment_Oct2012.csv'
state_data = pd.read_csv(state_unemployment)

m = folium.Map(location=[48, -102], zoom_start=3)

m.choropleth(
    geo_data=state_geo,
    name='choropleth',
    data=state_data,
    columns=['State', 'Unemployment'],
    key_on='feature.id',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Unemployment Rate (%)'
)


folium.LayerControl().add_to(m)

m
# Out:
# /usr/local/lib/python3.6/dist-packages/folium/folium.py:426: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium import plugins
m = folium.plugins.DualMap(location=(35.7243645,139.5105908),tiles=None, zoom_start=16)

fg_both = folium.FeatureGroup(name='markers_both').add_to(m)
fg_1 = folium.FeatureGroup(name='markers_1').add_to(m.m1)
fg_2 = folium.FeatureGroup(name='markers_2').add_to(m.m2)
folium.TileLayer('openstreetmap').add_to(m.m1)
folium.TileLayer('cartodbpositron').add_to(m.m2)

icon_red = folium.Icon(color='red')
folium.Marker((35.7243645,139.5105908), tooltip='both', icon=icon_red).add_to(fg_both)
folium.Marker((35.7243645,139.5116918), tooltip='1').add_to(fg_1)
folium.Marker((35.7243645,139.5105938), tooltip='2').add_to(fg_2)


folium.LayerControl(collapsed=False).add_to(m)
m.save('sheePark2.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
